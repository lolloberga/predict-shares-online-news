# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.svm import SVR

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df_dev = pd.read_csv('../dataset/development.csv')
df_eval = pd.read_csv('../dataset/evaluation.csv')

df = pd.concat([df_dev, df_eval], sort=False)
df.head()
# Out:
#    id                                                url  timedelta  \
# 0   0  http://mashable.com/2014/09/08/safest-cabbies-...      121.0
# 1   1   http://mashable.com/2013/07/25/3d-printed-rifle/      532.0
# 2   2  http://mashable.com/2013/10/30/digital-dinosau...      435.0
# 3   3  http://mashable.com/2014/08/27/homer-simpson-i...      134.0
# 4   4  http://mashable.com/2013/01/10/creepy-robotic-...      728.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0            1015.0         0.422018               1.0
# 1             9.0             503.0         0.569697               1.0
# 2             9.0             232.0         0.646018               1.0
# 3            12.0             171.0         0.722892               1.0
# 4            11.0             286.0         0.652632               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  ...  \
# 0                  0.545031       10.0             6.0  ...
# 1                  0.737542        9.0             0.0  ...
# 2                  0.748428       12.0             3.0  ...
# 3                  0.867925        9.0             5.0  ...
# 4                  0.800000        5.0             2.0  ...
#
#    avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0              -0.160714                  -0.50              -0.071429
# 1              -0.157500                  -0.25              -0.100000
# 2              -0.427500                  -1.00              -0.187500
# 3              -0.216667                  -0.25              -0.166667
# 4              -0.251786                  -0.50              -0.100000
#
#    title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0                 0.0                      0.00                     0.5
# 1                 0.0                      0.00                     0.5
# 2                 0.0                      0.00                     0.5
# 3                 0.4                     -0.25                     0.1
# 4                 0.2                     -0.10                     0.3
#
#    abs_title_sentiment_polarity   shares  data_channel    weekday
# 0                          0.00   2900.0           bus    tuesday
# 1                          0.00   1300.0          tech   thursday
# 2                          0.00  17700.0     lifestyle  wednesday
# 3                          0.25   1500.0           bus  wednesday
# 4                          0.10   1400.0          tech   thursday
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Preprocessing

# %%
def final_preprocessing(df, reduce_df=True):
    df_preproc = df.copy()

    # one hot encoding
    enc = OneHotEncoder()
    encoded_df = pd.concat([df_preproc['weekday'], df_preproc['data_channel']], axis=1)
    enc.fit(encoded_df)
    encoded_df = enc.transform(encoded_df)
    additional_columns = enc.get_feature_names_out()
    df_preproc[additional_columns] = encoded_df.toarray()
    df_preproc.drop(['weekday', 'data_channel', 'url', 'id'], axis = 1, inplace=True)

    # drop from feature selection
    df_preproc.drop(columns=['n_non_stop_words', 'kw_min_min', 'kw_max_max'], inplace=True)

    if reduce_df:
        # remove n_tokens_content less than 0
        df_preproc = df_preproc.query("n_tokens_content > 0")
        df_preproc['n_tokens_content'] = np.log(df_preproc['n_tokens_content'])
        # Remove outliers from kw_avg_avg (we lost another 9% of the dataset)
        q1 = df_preproc['kw_avg_avg'].describe()['25%']
        q3 = df_preproc['kw_avg_avg'].describe()['75%']
        iqr = q3 - q1
        min_kw_avg_avg = q1 - 1.5*iqr
        max_kw_avg_avg = q3 + 1.5*iqr
        df_preproc = df_preproc[(df_preproc.kw_avg_avg < max_kw_avg_avg) & (df_preproc.kw_avg_avg > min_kw_avg_avg)]
    else:
        df_preproc['n_tokens_content'] = np.log(1 + df_preproc['n_tokens_content'])

    # adjust num_imgs, num_self_hrefs, num_videos, num_hrefs
    df_preproc['num_imgs'].fillna(df_preproc['num_imgs'].mean(), inplace=True)
    df_preproc['num_imgs'] = np.log(1 + df_preproc['num_imgs'])
    df_preproc['num_self_hrefs'].fillna(df_preproc['num_self_hrefs'].mean(), inplace=True)
    df_preproc['num_self_hrefs'] = np.log(1 + df_preproc['num_self_hrefs'])
    df_preproc['num_videos'].fillna(df_preproc['num_videos'].mean(), inplace=True)
    df_preproc['num_videos'] = np.log(1 + df_preproc['num_videos'])
    df_preproc['num_hrefs'] = np.log(1 + df_preproc['num_hrefs'])

    std_scaler = StandardScaler().fit(df_preproc[['n_tokens_title', 'n_tokens_content']])
    scaled_features = std_scaler.transform(df_preproc[['n_tokens_title', 'n_tokens_content']])
    df_preproc[['n_tokens_title', 'n_tokens_content']] = scaled_features

    df_preproc['avg_negative_polarity'] = df_preproc['avg_negative_polarity'].abs()

    # Since this features has a range between [0, 10], we can apply a min max scaling
    df_preproc['num_keywords'] = df.groupby(['data_channel'], sort=False)['num_keywords'].apply(lambda x: x.fillna(x.mean())).reset_index()['num_keywords']
    std_scaler = MinMaxScaler().fit(df_preproc[['num_keywords']])
    scaled_features = std_scaler.transform(df_preproc[['num_keywords']])
    df_preproc[['num_keywords']] = scaled_features

    if 'shares' in df_preproc:
        df_preproc['shares'] = np.log(df_preproc['shares'])

    std_scaler = StandardScaler().fit(df_preproc[['kw_avg_max', 'kw_avg_avg', 'kw_avg_min', 'kw_min_avg', 'kw_max_avg', 'kw_max_min', 'kw_min_max']])
    scaled_features = std_scaler.transform(df_preproc[['kw_avg_max', 'kw_avg_avg', 'kw_avg_min', 'kw_min_avg','kw_max_avg', 'kw_max_min', 'kw_min_max']])
    df_preproc[['kw_avg_max', 'kw_avg_avg', 'kw_avg_min', 'kw_min_avg','kw_max_avg', 'kw_max_min', 'kw_min_max']] = scaled_features

    std_scaler = StandardScaler().fit(df_preproc[['self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess']])
    scaled_features = std_scaler.transform(df_preproc[['self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess']])
    df_preproc[['self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess']] = scaled_features


    is_weekend = []
    for _, row in df_preproc.iterrows():
        if row['weekday_sunday'] == 1 or row['weekday_saturday'] == 1:
            is_weekend.append(1)
        else:
            is_weekend.append(0)
    df_preproc['is_weekend'] = is_weekend

    std_scaler = StandardScaler().fit(df_preproc[['timedelta']])
    scaled_features = std_scaler.transform(df_preproc[['timedelta']])
    df_preproc[['timedelta']] = scaled_features

    return df_preproc

# %%
working_df_dev = final_preprocessing(df_dev)
df_working_df_eval = final_preprocessing(df_eval, reduce_df=False)
(len(df_working_df_eval), len(df_eval))
# Out:
# /var/tmp/ipykernel_271249/2523094066.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preproc['n_tokens_content'] = np.log(df_preproc['n_tokens_content'])
# /var/tmp/ipykernel_271249/2523094066.py:46: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_preproc['num_keywords'] = df.groupby(['data_channel'], sort=False)['num_keywords'].apply(lambda x: x.fillna(x.mean())).reset_index()['num_keywords']
# /var/tmp/ipykernel_271249/2523094066.py:46: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_preproc['num_keywords'] = df.groupby(['data_channel'], sort=False)['num_keywords'].apply(lambda x: x.fillna(x.mean())).reset_index()['num_keywords']
# (7917, 7917)

# %%
X = working_df_dev.drop(columns=["shares"]).values
y = working_df_dev["shares"].values

X_train, X_valid, y_train, y_valid = train_test_split(X, y, shuffle=True, random_state=42)

# %% [markdown]
#  ## Hyperparameter tuning

# %%
params = {
    "kernel": ['rbf'],
    "gamma": ['scale', 'auto'],
    "tol": [1e-3, 1e-4],
    "C": [0.5, 1, 2, 6],
    "epsilon": [0.3, 0.5, 1, 2, 6],
    "shrinking": [True, False]
}

# %%
# prova a non fare la cross validation!
gs = GridSearchCV(SVR(), param_grid=params, cv=5, scoring='r2', verbose=3)
gs.fit(X, y)
print(gs.best_score_)
print(gs.best_params_)
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.134 total time= 1.2min
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.126 total time= 1.1min
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.139 total time= 1.0min
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.152 total time= 1.0min
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.132 total time= 1.0min
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.134 total time= 1.0min
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.126 total time= 1.0min
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.139 total time= 1.0min
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.152 total time= 1.0min
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.132 total time= 1.0min
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.134 total time= 1.1min
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.126 total time= 1.1min
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.139 total time= 1.1min
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.152 total time= 1.1min
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.132 total time= 1.1min
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.134 total time= 1.2min
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.126 total time= 1.1min
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.139 total time= 1.1min
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.152 total time= 1.1min
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.132 total time= 1.1min
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.133 total time=  46.3s
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.124 total time=  45.8s
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.138 total time=  46.3s
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.149 total time=  45.5s
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.129 total time=  46.1s
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.133 total time=  45.0s
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.124 total time=  46.1s
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.138 total time= 1.0min
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.149 total time=  54.1s
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.129 total time= 1.0min
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.133 total time= 1.2min
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.124 total time= 1.2min
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.138 total time= 1.2min
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.149 total time= 1.1min
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.129 total time= 1.1min
# [CV 1/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.133 total time= 1.2min
# [CV 2/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.124 total time= 1.2min
# [CV 3/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.138 total time= 1.2min
# [CV 4/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.149 total time= 1.2min
# [CV 5/5] END C=0.5, epsilon=0.3, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.129 total time= 1.2min
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.148 total time=  45.8s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.138 total time=  46.2s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.154 total time=  46.1s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.162 total time=  47.3s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.144 total time=  46.4s
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.148 total time=  44.5s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.138 total time=  48.0s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.154 total time=  47.4s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.162 total time=  48.6s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=0.144 total time=  43.6s
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.148 total time=  48.2s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.138 total time=  46.8s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.154 total time=  47.5s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.162 total time=  50.4s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=0.144 total time=  51.5s
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.148 total time=  50.7s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.138 total time=  52.5s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.154 total time=  51.1s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.162 total time=  52.7s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=0.144 total time=  48.3s
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.146 total time=  44.5s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.136 total time=  44.2s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.153 total time=  44.4s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.160 total time=  46.9s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=0.142 total time=  46.5s
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.146 total time=  46.9s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.136 total time=  46.5s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.153 total time=  47.3s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.160 total time=  45.0s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=0.143 total time=  43.8s
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.146 total time=  47.0s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.136 total time=  46.9s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.153 total time=  47.5s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.160 total time=  47.9s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.142 total time=  47.7s
# [CV 1/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.146 total time=  49.1s
# [CV 2/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.136 total time=  48.5s
# [CV 3/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.153 total time=  50.1s
# [CV 4/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.160 total time=  49.1s
# [CV 5/5] END C=0.5, epsilon=0.5, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.143 total time=  48.0s
# [CV 1/5] END C=0.5, epsilon=1, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.106 total time=  19.3s
# [CV 2/5] END C=0.5, epsilon=1, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0
5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.107 total time=  17.6s
# [CV 2/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.102 total time=  17.2s
# [CV 3/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.135 total time=  17.2s
# [CV 4/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.122 total time=  17.3s
# [CV 5/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=0.112 total time=  16.8s
# [CV 1/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.107 total time=  18.7s
# [CV 2/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.102 total time=  18.9s
# [CV 3/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.135 total time=  18.6s
# [CV 4/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.122 total time=  18.4s
# [CV 5/5] END C=2, epsilon=1, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=0.112 total time=  18.5s
# [CV 1/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.282 total time=   2.3s
# [CV 2/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.288 total time=   2.1s
# [CV 3/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.217 total time=   2.3s
# [CV 4/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.315 total time=   2.2s
# [CV 5/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.271 total time=   2.3s
# [CV 1/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.282 total time=   2.2s
# [CV 2/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.288 total time=   2.1s
# [CV 3/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.217 total time=   2.2s
# [CV 4/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.315 total time=   2.3s
# [CV 5/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.271 total time=   2.3s
# [CV 1/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.282 total time=   2.5s
# [CV 2/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.288 total time=   2.4s
# [CV 3/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.217 total time=   2.5s
# [CV 4/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.315 total time=   2.5s
# [CV 5/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.271 total time=   2.6s
# [CV 1/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.282 total time=   2.8s
# [CV 2/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.288 total time=   2.6s
# [CV 3/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.217 total time=   2.8s
# [CV 4/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.315 total time=   2.7s
# [CV 5/5] END C=2, epsilon=2, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.271 total time=   2.7s
# [CV 1/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.274 total time=   2.2s
# [CV 2/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.288 total time=   2.1s
# [CV 3/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.209 total time=   2.2s
# [CV 4/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.307 total time=   2.3s
# [CV 5/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.264 total time=   2.2s
# [CV 1/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.274 total time=   2.3s
# [CV 2/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.288 total time=   2.2s
# [CV 3/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.209 total time=   2.2s
# [CV 4/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.307 total time=   2.2s
# [CV 5/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.264 total time=   2.1s
# [CV 1/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.274 total time=   2.5s
# [CV 2/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.288 total time=   2.3s
# [CV 3/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.209 total time=   2.4s
# [CV 4/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.307 total time=   2.5s
# [CV 5/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.264 total time=   2.4s
# [CV 1/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.274 total time=   2.7s
# [CV 2/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.288 total time=   2.5s
# [CV 3/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.209 total time=   2.7s
# [CV 4/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.307 total time=   2.6s
# [CV 5/5] END C=2, epsilon=2, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.264 total time=   2.5s
# [CV 1/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=-0.036 total time=   0.0s
# [CV 1/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.036 total time=   0.0s
# [CV 1/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.001;, score=-0.036 total time=   0.0s
# [CV 1/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=scale, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.036 total time=   0.0s
# [CV 1/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.001;, score=-0.035 total time=   0.0s
# [CV 1/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=True, tol=0.0001;, score=-0.035 total time=   0.0s
# [CV 1/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.001;, score=-0.035 total time=   0.0s
# [CV 1/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.042 total time=   0.0s
# [CV 2/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.009 total time=   0.0s
# [CV 3/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.194 total time=   0.0s
# [CV 4/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.040 total time=   0.0s
# [CV 5/5] END C=2, epsilon=6, gamma=auto, kernel=rbf, shrinking=False, tol=0.0001;, score=-0.035 total time=   0.0s
# [CV 1/5] END C=6, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.135 total time= 1.1min
# [CV 2/5] END C=6, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.127 total time= 1.1min
# [CV 3/5] END C=6, epsilon=0.3, gamma=scale, kernel=rbf, shrinking=True, tol=0.001;, score=0.143 total time= 1.1min

# %% [markdown]
# ## Generate final CSV

# %%
X = working_df_dev.drop(columns=["shares"]).values
y = working_df_dev["shares"].values
svr = SVR(gs.best_params_)
svr.fit(X,y)

# %%
# Make final predictions
y_pred = gs.predict(df_working_df_eval.values)
# Write CSV
id_col = df_eval['id']
new_df = pd.DataFrame(columns=['Id', 'Predicted'])
new_df['Id'] = id_col
new_df['Predicted'] = y_pred
new_df.to_csv('../output/NAME.csv', columns=['Id','Predicted'], index=False)
