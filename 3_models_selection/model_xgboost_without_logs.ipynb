# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import sklearn

from sklearn.model_selection import train_test_split, GridSearchCV

from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df_dev = pd.read_csv('../dataset/development.csv')
df_eval = pd.read_csv('../dataset/evaluation.csv')

df = pd.concat([df_dev, df_eval], sort=False)
df.head()
# Out:
#    id                                                url  timedelta  \
# 0   0  http://mashable.com/2014/09/08/safest-cabbies-...      121.0
# 1   1   http://mashable.com/2013/07/25/3d-printed-rifle/      532.0
# 2   2  http://mashable.com/2013/10/30/digital-dinosau...      435.0
# 3   3  http://mashable.com/2014/08/27/homer-simpson-i...      134.0
# 4   4  http://mashable.com/2013/01/10/creepy-robotic-...      728.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0            1015.0         0.422018               1.0
# 1             9.0             503.0         0.569697               1.0
# 2             9.0             232.0         0.646018               1.0
# 3            12.0             171.0         0.722892               1.0
# 4            11.0             286.0         0.652632               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  ...  \
# 0                  0.545031       10.0             6.0  ...
# 1                  0.737542        9.0             0.0  ...
# 2                  0.748428       12.0             3.0  ...
# 3                  0.867925        9.0             5.0  ...
# 4                  0.800000        5.0             2.0  ...
#
#    avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0              -0.160714                  -0.50              -0.071429
# 1              -0.157500                  -0.25              -0.100000
# 2              -0.427500                  -1.00              -0.187500
# 3              -0.216667                  -0.25              -0.166667
# 4              -0.251786                  -0.50              -0.100000
#
#    title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0                 0.0                      0.00                     0.5
# 1                 0.0                      0.00                     0.5
# 2                 0.0                      0.00                     0.5
# 3                 0.4                     -0.25                     0.1
# 4                 0.2                     -0.10                     0.3
#
#    abs_title_sentiment_polarity   shares  data_channel    weekday
# 0                          0.00   2900.0           bus    tuesday
# 1                          0.00   1300.0          tech   thursday
# 2                          0.00  17700.0     lifestyle  wednesday
# 3                          0.25   1500.0           bus  wednesday
# 4                          0.10   1400.0          tech   thursday
#
# [5 rows x 50 columns]

# %%
df_dev.shape
# Out:
# (31715, 50)

# %% [markdown]
# ## Preprocessing

# %%
def final_preprocessing(df, reduce_df=True):
    df_preproc = df.copy()

    # one hot encoding
    enc = OneHotEncoder()
    encoded_df = pd.concat([df_preproc['weekday'], df_preproc['data_channel']], axis=1)
    enc.fit(encoded_df)
    encoded_df = enc.transform(encoded_df)
    additional_columns = enc.get_feature_names_out()
    df_preproc[additional_columns] = encoded_df.toarray()
    df_preproc.drop(['weekday', 'data_channel', 'url', 'id'], axis = 1, inplace=True)

    # drop from feature selection
    df_preproc.drop(columns=['n_non_stop_words', 'kw_min_min', 'kw_max_max'], inplace=True)

    if reduce_df:
        # remove n_tokens_content less than 0
        df_preproc = df_preproc.query("n_tokens_content > 0")
        df_preproc['n_tokens_content'] = np.log(df_preproc['n_tokens_content'])
        # Remove outliers from kw_avg_avg (we lost another 9% of the dataset)
        q1 = df_preproc['kw_avg_avg'].describe()['25%']
        q3 = df_preproc['kw_avg_avg'].describe()['75%']
        iqr = q3 - q1
        min_kw_avg_avg = q1 - 1.5*iqr
        max_kw_avg_avg = q3 + 1.5*iqr
        df_preproc = df_preproc[(df_preproc.kw_avg_avg < max_kw_avg_avg) & (df_preproc.kw_avg_avg > min_kw_avg_avg)]
    else:
        df_preproc['n_tokens_content'] = np.log(1 + df_preproc['n_tokens_content'])

    # adjust num_imgs, num_self_hrefs, num_videos, num_hrefs
    df_preproc['num_imgs'].fillna(df_preproc['num_imgs'].mean(), inplace=True)
    df_preproc['num_imgs'] = np.log(1 + df_preproc['num_imgs'])
    df_preproc['num_self_hrefs'].fillna(df_preproc['num_self_hrefs'].mean(), inplace=True)
    df_preproc['num_self_hrefs'] = np.log(1 + df_preproc['num_self_hrefs'])
    df_preproc['num_videos'].fillna(df_preproc['num_videos'].mean(), inplace=True)
    df_preproc['num_videos'] = np.log(1 + df_preproc['num_videos'])
    df_preproc['num_hrefs'] = np.log(1 + df_preproc['num_hrefs'])

    std_scaler = StandardScaler().fit(df_preproc[['n_tokens_title', 'n_tokens_content']])
    scaled_features = std_scaler.transform(df_preproc[['n_tokens_title', 'n_tokens_content']])
    df_preproc[['n_tokens_title', 'n_tokens_content']] = scaled_features

    df_preproc['avg_negative_polarity'] = df_preproc['avg_negative_polarity'].abs()

    # Since this features has a range between [0, 10], we can apply a min max scaling
    df_preproc['num_keywords'] = df.groupby(['data_channel'], sort=False)['num_keywords'].apply(lambda x: x.fillna(x.mean())).reset_index()['num_keywords']
    std_scaler = MinMaxScaler().fit(df_preproc[['num_keywords']])
    scaled_features = std_scaler.transform(df_preproc[['num_keywords']])
    df_preproc[['num_keywords']] = scaled_features

    if 'shares' in df_preproc:
        df_preproc['shares'] = np.log(df_preproc['shares'])

    std_scaler = StandardScaler().fit(df_preproc[['kw_avg_max', 'kw_avg_avg', 'kw_avg_min', 'kw_min_avg', 'kw_max_avg', 'kw_max_min', 'kw_min_max']])
    scaled_features = std_scaler.transform(df_preproc[['kw_avg_max', 'kw_avg_avg', 'kw_avg_min', 'kw_min_avg','kw_max_avg', 'kw_max_min', 'kw_min_max']])
    df_preproc[['kw_avg_max', 'kw_avg_avg', 'kw_avg_min', 'kw_min_avg','kw_max_avg', 'kw_max_min', 'kw_min_max']] = scaled_features

    std_scaler = StandardScaler().fit(df_preproc[['self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess']])
    scaled_features = std_scaler.transform(df_preproc[['self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess']])
    df_preproc[['self_reference_min_shares', 'self_reference_max_shares', 'self_reference_avg_sharess']] = scaled_features


    is_weekend = []
    for _, row in df_preproc.iterrows():
        if row['weekday_sunday'] == 1 or row['weekday_saturday'] == 1:
            is_weekend.append(1)
        else:
            is_weekend.append(0)
    df_preproc['is_weekend'] = is_weekend

    std_scaler = StandardScaler().fit(df_preproc[['timedelta']])
    scaled_features = std_scaler.transform(df_preproc[['timedelta']])
    df_preproc[['timedelta']] = scaled_features

    return df_preproc

# %%
working_df_dev = final_preprocessing(df_dev)
df_working_df_eval = final_preprocessing(df_eval, reduce_df=False)
(len(df_working_df_eval), len(df_eval))
# Out:
# /var/tmp/ipykernel_357577/2523094066.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_preproc['n_tokens_content'] = np.log(df_preproc['n_tokens_content'])
# /var/tmp/ipykernel_357577/2523094066.py:46: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_preproc['num_keywords'] = df.groupby(['data_channel'], sort=False)['num_keywords'].apply(lambda x: x.fillna(x.mean())).reset_index()['num_keywords']
# /var/tmp/ipykernel_357577/2523094066.py:46: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_preproc['num_keywords'] = df.groupby(['data_channel'], sort=False)['num_keywords'].apply(lambda x: x.fillna(x.mean())).reset_index()['num_keywords']
# (7917, 7917)

# %% [markdown]
# ## Hyperparameter tuning

# %%
X = working_df_dev.drop(columns=["shares"]).values
y = working_df_dev["shares"].values

X_train, X_valid, y_train, y_valid = train_test_split(X, y, shuffle=True, random_state=42)

# %%
params = {
    "n_estimators": [50, 100, 200, 300],
    "max_depth": [8,12],
    "min_child_weight": [15, 20, 25],
    "eta": [0.001, 0.0025, 0.005, 0.01, 0.025, 0.05],
    "eval_metric": ['rmse'], # mean_squared_error
}

# %%
gs = GridSearchCV(XGBRegressor(), param_grid=params, cv=5, scoring='neg_root_mean_squared_error', verbose=3)
gs.fit(X, y)
print(gs.best_score_)
print(gs.best_params_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=50;, score=-6.661 total time=   0.9s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=50;, score=-6.665 total time=   1.0s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=50;, score=-6.681 total time=   1.0s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=50;, score=-6.665 total time=   1.1s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=50;, score=-6.676 total time=   0.9s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=100;, score=-6.341 total time=   1.5s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=100;, score=-6.345 total time=   1.6s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=100;, score=-6.362 total time=   1.8s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=100;, score=-6.345 total time=   2.2s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=100;, score=-6.357 total time=   1.8s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=200;, score=-5.748 total time=   3.4s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=200;, score=-5.752 total time=   3.4s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=200;, score=-5.770 total time=   3.2s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=200;, score=-5.752 total time=   3.2s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=200;, score=-5.765 total time=   3.1s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=300;, score=-5.212 total time=   5.6s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=300;, score=-5.217 total time=   6.7s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=300;, score=-5.236 total time=   6.0s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=300;, score=-5.216 total time=   5.9s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=15, n_estimators=300;, score=-5.230 total time=   5.3s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=50;, score=-6.661 total time=   0.7s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=50;, score=-6.665 total time=   0.9s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=50;, score=-6.681 total time=   0.8s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=50;, score=-6.665 total time=   1.0s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=50;, score=-6.676 total time=   0.8s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=100;, score=-6.341 total time=   1.5s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=100;, score=-6.345 total time=   1.7s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=100;, score=-6.362 total time=   1.6s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=100;, score=-6.345 total time=   1.5s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=100;, score=-6.357 total time=   1.8s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=200;, score=-5.748 total time=   3.5s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=200;, score=-5.752 total time=   3.2s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=200;, score=-5.770 total time=   3.4s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=200;, score=-5.752 total time=   3.6s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=200;, score=-5.765 total time=   3.8s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=300;, score=-5.212 total time=   5.4s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=300;, score=-5.217 total time=   5.6s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=300;, score=-5.236 total time=   5.7s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=300;, score=-5.216 total time=   6.1s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=20, n_estimators=300;, score=-5.230 total time=   5.7s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=50;, score=-6.661 total time=   0.9s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=50;, score=-6.665 total time=   1.0s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=50;, score=-6.681 total time=   1.1s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=50;, score=-6.665 total time=   0.8s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=50;, score=-6.676 total time=   1.0s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=100;, score=-6.341 total time=   1.8s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=100;, score=-6.345 total time=   1.8s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=100;, score=-6.362 total time=   1.6s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=100;, score=-6.345 total time=   1.7s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=100;, score=-6.357 total time=   1.6s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=200;, score=-5.748 total time=   3.7s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=200;, score=-5.752 total time=   3.5s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=200;, score=-5.770 total time=   3.3s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=200;, score=-5.752 total time=   3.9s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=200;, score=-5.765 total time=   3.6s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=300;, score=-5.212 total time=   5.6s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=300;, score=-5.217 total time=   5.5s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=300;, score=-5.236 total time=   5.4s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=300;, score=-5.216 total time=   5.4s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=8, min_child_weight=25, n_estimators=300;, score=-5.230 total time=   5.6s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=50;, score=-6.661 total time=   0.8s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=50;, score=-6.665 total time=   1.1s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=50;, score=-6.681 total time=   1.3s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=50;, score=-6.665 total time=   1.0s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=50;, score=-6.676 total time=   0.9s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=100;, score=-6.341 total time=   1.7s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=100;, score=-6.345 total time=   1.6s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=100;, score=-6.362 total time=   1.7s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=100;, score=-6.345 total time=   1.6s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=100;, score=-6.357 total time=   1.6s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=200;, score=-5.748 total time=   3.7s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=200;, score=-5.752 total time=   3.2s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=200;, score=-5.770 total time=   3.5s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=200;, score=-5.752 total time=   3.4s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=200;, score=-5.765 total time=   3.5s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=300;, score=-5.212 total time=   6.2s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=300;, score=-5.217 total time=   5.9s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=300;, score=-5.236 total time=   5.6s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=300;, score=-5.216 total time=   5.8s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=15, n_estimators=300;, score=-5.230 total time=   5.9s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=50;, score=-6.661 total time=   0.9s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=50;, score=-6.665 total time=   0.8s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=50;, score=-6.681 total time=   0.8s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=50;, score=-6.665 total time=   0.8s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=50;, score=-6.676 total time=   1.0s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=100;, score=-6.341 total time=   1.7s
# [CV 2/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=100;, score=-6.345 total time=   1.7s
# [CV 3/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=100;, score=-6.362 total time=   1.6s
# [CV 4/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=100;, score=-6.345 total time=   1.6s
# [CV 5/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=100;, score=-6.357 total time=   1.5s
# [CV 1/5] END eta=0.001, eval_metric=rmse, max_depth=12, min_child_weight=20, n_estimators=200;, score=
g_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_negative_likelihood_ratio',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'positive_likelihood_ratio',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'top_k_accuracy',
#  'v_measure_score']

# %% [markdown]
# All the features has been used to train xgboost regressor and others. I tried also to decrease the number but the score decreases

# %%
rms = mean_squared_error(y_valid, gs.predict(X_valid), squared=False)
print(rms)
r2 = r2_score(y_valid, gs.predict(X_valid))
adj_r2 = 1-(1-r2)*(len(X_valid) - 1)/(len(X_valid) - X_valid.shape[1] - 1)
print(adj_r2)
# Out:
# 0.6909087117566126
# 0.39373177018297556

# %% [markdown]
# Recall that for each of these models you can check the feature importance, so that remove some features

# %%
feature_names = working_df_dev.drop(columns=["shares"]).columns
sorted(zip(feature_names, xgb_r.feature_importances_), key=lambda x: x[1], reverse=True)
# Out:
# [('data_channel_tech', 0.1563371),
#  ('kw_avg_avg', 0.12027372),
#  ('data_channel_socmed', 0.07851338),
#  ('data_channel_entertainment', 0.07000306),
#  ('is_weekend', 0.056433074),
#  ('data_channel_lifestyle', 0.033759877),
#  ('kw_min_avg', 0.033008665),
#  ('data_channel_world', 0.03147098),
#  ('num_hrefs', 0.026406191),
#  ('min_positive_polarity', 0.025813013),
#  ('global_subjectivity', 0.02474313),
#  ('num_videos', 0.0245458),
#  ('kw_avg_max', 0.024481896),
#  ('num_imgs', 0.022690505),
#  ('title_subjectivity', 0.022096708),
#  ('title_sentiment_polarity', 0.021878142),
#  ('global_sentiment_polarity', 0.021053853),
#  ('n_tokens_content', 0.020581577),
#  ('average_token_length', 0.020086395),
#  ('global_rate_negative_words', 0.020071955),
#  ('avg_negative_polarity', 0.02002607),
#  ('n_non_stop_unique_tokens', 0.020018425),
#  ('rate_negative_words', 0.019788092),
#  ('avg_positive_polarity', 0.019588307),
#  ('global_rate_positive_words', 0.01914742),
#  ('max_positive_polarity', 0.018795239),
#  ('num_keywords', 0.015723076),
#  ('n_tokens_title', 0.012664358)]

# %%
X = working_df_dev.drop(columns=["shares"]).values
y = working_df_dev["shares"].values

# %%
gs.best_params_
# Out:
# {'eta': 0.025,
#  'eval_metric': 'rmse',
#  'max_depth': 8,
#  'min_child_weight': 25,
#  'n_estimators': 300}

# %%
xgbr = XGBRegressor(eta = 0.025, eval_metric = 'rmse', max_depth=4, min_child_weight=15)
xgbr.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.025, eval_metric='rmse',
#              feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=15, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, predictor=None, ...)

# %% [markdown]
# ## Generate final CSV

# %%
# Get the best configuration from the grid search
# Out:
# array([2267.4316, 2329.6162, 2231.1514, ..., 2158.7778, 2906.3823,
#        2094.9004], dtype=float32)

# %%
# Make final predictions
y_pred = gs.predict(df_working_df_eval.values)
final_preds = np.exp(y_pred)
# Write CSV
id_col = df_eval['id']
new_df = pd.DataFrame(columns=['Id', 'Predicted'])
new_df['Id'] = id_col
new_df['Predicted'] = final_preds
new_df.to_csv('../output/xgboost.csv', columns=['Id','Predicted'], index=False)

# %%
new_df.describe()
# Out:
#                  Id    Predicted
# count   7917.000000  7917.000000
# mean   35679.634584  1776.805786
# std     2289.051312   645.315063
# min    31715.000000   385.111969
# 25%    33699.000000  1308.583496
# 50%    35680.000000  1645.887451
# 75%    37661.000000  2096.386963
# max    39643.000000  7491.833984
